# %%
# data preprocessing

import numpy as np;
import pandas as pd;

# %%
df=pd.read_csv("../data/Data.csv");

# %%
df.head(2)

# %%
x = df.iloc[:,:-1].values #.values is used to conert data into array.

# %%
x

# %%
y = df.iloc[:,3].values

# %%
y

# %%
x.shape

# %%
y.shape

# %%
#Q WAP to Perform data preprocessing

df.isnull().sum()  #sum is used to print null values in each column

# %%
df.fillna(0) # one way to handel null

# %%
df.dropna(how = 'any') #drop null values   any/all

# %%
df.fillna(method = 'ffill') #forwardfill   bfill -> backwardfill.
